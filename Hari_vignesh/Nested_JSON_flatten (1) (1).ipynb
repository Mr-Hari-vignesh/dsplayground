# %% [markdown]
# #pip installing Dataprofiler to our notebook
#
# (NOTE: Always pip install everything in starting of our notebook because it will restart the terminal )

# %%
pip install DataProfiler[full]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting DataProfiler[full]
#   Downloading DataProfiler-0.8.3-py3-none-any.whl (12.1 MB)
# Collecting typing-extensions==3.10.0.2
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: six&gt;=1.15.0 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (1.15.0)
# Requirement already satisfied: h5py&gt;=2.10.0 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (3.1.0)
# Requirement already satisfied: chardet&gt;=3.0.4 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (4.0.0)
# Collecting fastavro&gt;=1.0.0.post1
#   Downloading fastavro-1.7.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
# Requirement already satisfied: psutil&gt;=4.0.0 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (5.8.0)
# Requirement already satisfied: scipy&gt;=1.4.1 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (1.6.2)
# Requirement already satisfied: pyarrow&gt;=1.0.1 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (4.0.0)
# Collecting requests==2.27.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting networkx==2.5.1
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: wheel&gt;=0.33.1 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (0.36.2)
# Requirement already satisfied: future&gt;=0.18.2 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (0.18.2)
# Requirement already satisfied: pandas&gt;=1.1.2 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (1.2.4)
# Collecting python-snappy&gt;=0.5.4
#   Downloading python_snappy-0.6.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (56 kB)
# Collecting charset-normalizer&gt;=1.3.6
#   Downloading charset_normalizer-3.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
# Collecting numpy&gt;=1.21.1
#   Downloading numpy-1.23.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Requirement already satisfied: pytz&gt;=2020.1 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (2020.5)
# Requirement already satisfied: python-dateutil&gt;=2.7.5 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (2.8.1)
# Collecting rapidfuzz&gt;=2.6.1
#   Downloading rapidfuzz-2.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Requirement already satisfied: seaborn&gt;=0.11.1 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (0.11.1)
# Requirement already satisfied: scikit-learn&gt;=0.23.2 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (0.24.1)
# Requirement already satisfied: matplotlib&lt;3.6.1,&gt;=3.3.3 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (3.4.2)
# Collecting tensorflow-gpu&gt;=2.6.4
#   Downloading tensorflow_gpu-2.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
# Requirement already satisfied: tqdm&gt;=4.0.0 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (4.59.0)
# Requirement already satisfied: keras&gt;=2.4.3 in /databricks/python3/lib/python3.8/site-packages (from DataProfiler[full]) (2.6.0)
# Collecting decorator&lt;5,&gt;=4.3
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests==2.27.1-&gt;DataProfiler[full]) (2020.12.5)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests==2.27.1-&gt;DataProfiler[full]) (1.25.11)
# Requirement already satisfied: idna&lt;4,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests==2.27.1-&gt;DataProfiler[full]) (2.10)
# Collecting charset-normalizer&gt;=1.3.6
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: pillow&gt;=6.2.0 in /databricks/python3/lib/python3.8/site-packages (from matplotlib&lt;3.6.1,&gt;=3.3.3-&gt;DataProfiler[full]) (8.2.0)
# Requirement already satisfied: cycler&gt;=0.10 in /databricks/python3/lib/python3.8/site-packages (from matplotlib&lt;3.6.1,&gt;=3.3.3-&gt;DataProfiler[full]) (0.10.0)
# Requirement already satisfied: kiwisolver&gt;=1.0.1 in /databricks/python3/lib/python3.8/site-packages (from matplotlib&lt;3.6.1,&gt;=3.3.3-&gt;DataProfiler[full]) (1.3.1)
# Requirement already satisfied: pyparsing&gt;=2.2.1 in /databricks/python3/lib/python3.8/site-packages (from matplotlib&lt;3.6.1,&gt;=3.3.3-&gt;DataProfiler[full]) (2.4.7)
# Requirement already satisfied: joblib&gt;=0.11 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn&gt;=0.23.2-&gt;DataProfiler[full]) (1.0.1)
# Requirement already satisfied: threadpoolctl&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn&gt;=0.23.2-&gt;DataProfiler[full]) (2.1.0)
# Collecting numpy&gt;=1.21.1
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# Requirement already satisfied: opt-einsum&gt;=2.3.2 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (3.3.0)
# Collecting libclang&gt;=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
# Collecting flatbuffers&gt;=2.0
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (52.0.0)
# Requirement already satisfied: wrapt&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (1.12.1)
# Collecting absl-py&gt;=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: keras-preprocessing&gt;=1.1.1 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (1.1.2)
# Collecting tensorflow-estimator&lt;2.11,&gt;=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting tensorboard&lt;2.11,&gt;=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: grpcio&lt;2.0,&gt;=1.24.3 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (1.39.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (20.9)
# Requirement already satisfied: termcolor&gt;=1.1.0 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (1.1.0)
# Requirement already satisfied: google-pasta&gt;=0.1.1 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (0.2.0)
# Collecting keras&gt;=2.4.3
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: astunparse&gt;=1.6.0 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (1.6.3)
# Collecting tensorflow-io-gcs-filesystem&gt;=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Requirement already satisfied: protobuf&lt;3.20,&gt;=3.9.2 in /databricks/python3/lib/python3.8/site-packages (from tensorflow-gpu&gt;=2.6.4-&gt;DataProfiler[full]) (3.17.2)
# Requirement already satisfied: gast&lt;=0.4.0,&gt;=0.2.1 in /databricks/python3/l

# %% [markdown]
# #Mounting the data from microsoft Azure storage (bronze layer)

# %%
# %fs
ls /mnt/tf-abfss/bronze/indian_railways
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/tf-abfss/bronze/indian_railways/Posts.xml</td><td>Posts.xml</td><td>43257032</td></tr><tr><td>dbfs:/mnt/tf-abfss/bronze/indian_railways/schedules.json</td><td>schedules.json</td><td>82174280</td></tr><tr><td>dbfs:/mnt/tf-abfss/bronze/indian_railways/stations.json</td><td>stations.json</td><td>1864683</td></tr><tr><td>dbfs:/mnt/tf-abfss/bronze/indian_railways/trains.json</td><td>trains.json</td><td>14768598</td></tr></tbody></table></div>

# %% [markdown]
# #Importing the required library for our notebook

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Attaching the data and viewing the Nested JSON data

# %%
df = spark.read.option("multiline","true").json("/mnt/tf-abfss/bronze/indian_railways/stations.json")
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- features: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- geometry: struct (nullable = true)
#     |    |    |-- coordinates: array (nullable = true)
#     |    |    |    |-- element: double (containsNull = true)
#     |    |    |-- type: string (nullable = true)
#     |    |-- properties: struct (nullable = true)
#     |    |    |-- address: string (nullable = true)
#     |    |    |-- code: string (nullable = true)
#     |    |    |-- name: string (nullable = true)
#     |    |    |-- state: string (nullable = true)
#     |    |    |-- zone: string (nullable = true)
#     |    |-- type: string (nullable = true)
# -- type: string (nullable = true)
#
# </div>

# %% [markdown]
# #Orginal look of json data

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>type</th></tr></thead><tbody><tr><td>List(List(List(List(75.4516454, 27.2520587), Point), List(Kishangarh Renwal, Rajasthan, BDHL, Badhal, Rajasthan, NWR), Feature), List(null, List(null, XX-BECE, XX-BECE, null, null), Feature), List(null, List(null, XX-BSPY, XX-BSPY, null, null), Feature), List(null, List(null, YY-BPLC, YY-BPLC, null, null), Feature), List(List(List(79.519746, 28.913427000000002), Point), List(Kichha, Uttar Pradesh, KHH, KICHHA, Uttar Pradesh, NER), Feature), List(List(List(74.43499088287354, 29.55519806064484), Point), List(MDR 89, Rajasthan, SRKN, Sherekan, Rajasthan, NWR), Feature), List(List(List(74.75103096105158, 29.238227312503696), Point), List(Bhukarka, Rajasthan, BKKA, Bhukarka, Rajasthan, NWR), Feature), List(List(List(74.77362781763077, 29.192562738768984), Point), List(State Highway 36, Rajasthan, NHR, Nohar, Rajasthan, NWR), Feature), List(List(List(80.231363, 12.975217), Point), List(Chennai, Tamil Nadu, PRGD, Perungudi, Tamil Nadu, SR), Feature), List(List(List(74.7179570607841, 29.345637263205944), Point), List(State Highway 23, Haryana, KNNA, Khinaniyan, Haryana, NWR), Feature), List(List(List(78.216684, 21.838466), Point), List(null, JKR, JAULKHERA, null, null), Feature), List(List(List(78.03136099999999, 21.909813), Point), List(null, BYS, BARSALI, null, null), Feature), List(List(List(78.936311, 23.838185999999997), Point), List(null, GW, GIRWAR, null, null), Feature), List(List(List(79.019912, 23.871771000000003), Point), List(null, DGD, DANGIDHAR, null, null), Feature), List(List(List(75.10354600000001, 23.770740999999997), Point), List(Dhodar, Madhya Pradesh, DOD, DHODHAR, Madhya Pradesh, WR), Feature), List(List(List(79.074633, 23.895862), Point), List(null, GAJ, GANESHGANJ, null, null), Feature), List(List(List(88.415324, 22.168635), Point), List(Jaynagar, West Bengal, JNM, Jayanagar Majilpur Halt, West Bengal, ER), Feature), List(List(List(74.71699100000001, 26.294459999999997), Point), List(Nasirabad, Rajasthan, NSD, NASIRABAD, Rajasthan, NWR), Feature), List(List(List(79.192899, 23.905726), Point), List(null, PHA, PATHARIA, null, null), Feature), List(List(List(78.103238, 18.679164999999998), Point), List(Nizamabad, Andhra Pradesh, NZB, NIZAMABAD, Andhra Pradesh, SCR), Feature), List(List(List(86.01054599999999, 25.387446999999998), Point), List(null, RJO, RAJENDRA PUL, null, null), Feature), List(List(List(79.478668, 11.009165), Point), List(Aduthurai, Tamil Nadu, ADT, ADUTURAI, Tamil Nadu, SR), Feature), List(List(List(79.388644, 10.952962), Point), List(Kumbakonam, Tamil Nadu, KMU, KUMBAKONAM, Tamil Nadu, SR), Feature), List(List(List(78.45351, 9.681538999999999), Point), List(Sivaganga, Tamil Nadu, MNM, MANAMADURAI JN, Tamil Nadu, SR), Feature), List(List(List(83.381499, 26.759311), Point), List(null, GKP, GORAKHPUR JN, null, null), Feature), List(null, List(null, BJUP, BJUP, null, null), Feature), List(List(List(73.16928300000001, 22.184274000000002), Point), List(null, VRM, VARNAMA, null, null), Feature), List(List(List(83.416821, 26.750649), Point), List(null, GKC, GORAKHPUR CANT, null, null), Feature), List(List(List(73.156746, 22.149889), Point), List(null, ITA, ITOLA, null, null), Feature), List(null, List(null, CIKA, CIKA, null, null), Feature), List(null, List(null, XX-CPHO, XX-CPHO, null, null), Feature), List(List(List(77.273006, 29.09692), Point), List(Baraut, Uttar Pradesh, BTU, BARAUT, Uttar Pradesh, NR), Feature), List(List(List(75.16846699999999, 30.817296), Point), List(Moga, Punjab, MOGA, Moga, Punjab, NR), Feature), List(List(List(70.503394, 23.309819), Point), List(null, SIOB, SAMAKHIALI JN, null, null), Feature), List(null, List(null, LLHW, LLHW, null, null), Feature), List(List(List(75.087121, 27.713786000000002), Point), List(MDR 87, Rajasthan, RDK, Rasheedpura Khori, Rajasthan, NWR), Feature), List(List(List(80.612645, 1 ...

# %% [markdown]
# #Defining a program to flatten the Nested JSON data

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

#Flatten array of structs and structs
def flatten(df):
   # compute Complex Fields (Lists and Structs) in Schema   
   complex_fields = dict([(field.name, field.dataType) ##---------It takes all the list of (fields) along with its (datatypes) in dictonary
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType]) ##-----it is checking whether it is                                                                                                                   (arraytype or structtype) 
   while len(complex_fields)!=0:
      col_name=list(complex_fields.keys())[0]
      print ("Processing :"+col_name+" Type : "+str(type(complex_fields[col_name])))#---to check the type of thr perticular field
    
      # if StructType then convert all sub element to columns.
      # i.e. flatten structs
      if (type(complex_fields[col_name]) == StructType): #---------
         expanded = [col(col_name+'.'+k).alias(col_name+'_'+k) for k in [ n.name for n in  complex_fields[col_name]]]
         df=df.select("*", *expanded).drop(col_name)
    
      # if ArrayType then add the Array Elements as Rows using the explode function
      # i.e. explode Arrays
      elif (type(complex_fields[col_name]) == ArrayType):    
         df=df.withColumn(col_name,explode_outer(col_name))
    
      # recompute remaining Complex Fields in Schema       
      complex_fields = dict([(field.name, field.dataType)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
   return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #After flatten the Nested Json data

# %%
df_flatten = flatten(df)
display(df_flatten)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Processing :features Type : &lt;class &#39;pyspark.sql.types.ArrayType&#39;&gt;
# Processing :features Type : &lt;class &#39;pyspark.sql.types.StructType&#39;&gt;
# Processing :features_geometry Type : &lt;class &#39;pyspark.sql.types.StructType&#39;&gt;
# Processing :features_properties Type : &lt;class &#39;pyspark.sql.types.StructType&#39;&gt;
# Processing :features_geometry_coordinates Type : &lt;class &#39;pyspark.sql.types.ArrayType&#39;&gt;
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>type</th><th>features_type</th><th>features_geometry_coordinates</th><th>features_geometry_type</th><th>features_properties_address</th><th>features_properties_code</th><th>features_properties_name</th><th>features_properties_state</th><th>features_properties_zone</th></tr></thead><tbody><tr><td>FeatureCollection</td><td>Feature</td><td>75.4516454</td><td>Point</td><td>Kishangarh Renwal, Rajasthan</td><td>BDHL</td><td>Badhal</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>27.2520587</td><td>Point</td><td>Kishangarh Renwal, Rajasthan</td><td>BDHL</td><td>Badhal</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>null</td><td>null</td><td>null</td><td>XX-BECE</td><td>XX-BECE</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>null</td><td>null</td><td>null</td><td>XX-BSPY</td><td>XX-BSPY</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>null</td><td>null</td><td>null</td><td>YY-BPLC</td><td>YY-BPLC</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>79.519746</td><td>Point</td><td>Kichha, Uttar Pradesh</td><td>KHH</td><td>KICHHA</td><td>Uttar Pradesh</td><td>NER</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>28.913427000000002</td><td>Point</td><td>Kichha, Uttar Pradesh</td><td>KHH</td><td>KICHHA</td><td>Uttar Pradesh</td><td>NER</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>74.43499088287354</td><td>Point</td><td>MDR 89, Rajasthan</td><td>SRKN</td><td>Sherekan</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>29.55519806064484</td><td>Point</td><td>MDR 89, Rajasthan</td><td>SRKN</td><td>Sherekan</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>74.75103096105158</td><td>Point</td><td>Bhukarka, Rajasthan</td><td>BKKA</td><td>Bhukarka</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>29.238227312503696</td><td>Point</td><td>Bhukarka, Rajasthan</td><td>BKKA</td><td>Bhukarka</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>74.77362781763077</td><td>Point</td><td>State Highway 36, Rajasthan</td><td>NHR</td><td>Nohar</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>29.192562738768984</td><td>Point</td><td>State Highway 36, Rajasthan</td><td>NHR</td><td>Nohar</td><td>Rajasthan</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>80.231363</td><td>Point</td><td>Chennai, Tamil Nadu</td><td>PRGD</td><td>Perungudi</td><td>Tamil Nadu</td><td>SR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>12.975217</td><td>Point</td><td>Chennai, Tamil Nadu</td><td>PRGD</td><td>Perungudi</td><td>Tamil Nadu</td><td>SR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>74.7179570607841</td><td>Point</td><td>State Highway 23, Haryana</td><td>KNNA</td><td>Khinaniyan</td><td>Haryana</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>29.345637263205944</td><td>Point</td><td>State Highway 23, Haryana</td><td>KNNA</td><td>Khinaniyan</td><td>Haryana</td><td>NWR</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>78.216684</td><td>Point</td><td>null</td><td>JKR</td><td>JAULKHERA</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>21.838466</td><td>Point</td><td>null</td><td>JKR</td><td>JAULKHERA</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>78.03136099999999</td><td>Point</td><td>null</td><td>BYS</td><td>BARSALI</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</td><td>Feature</td><td>21.909813</td><td>Point</td><td>null</td><td>BYS</td><td>BARSALI</td><td>null</td><td>null</td></tr><tr><td>FeatureCollection</ ...

# %%
df_flatten.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- type: string (nullable = true)
# -- features_type: string (nullable = true)
# -- features_geometry_coordinates: double (nullable = true)
# -- features_geometry_type: string (nullable = true)
# -- features_properties_address: string (nullable = true)
# -- features_properties_code: string (nullable = true)
# -- features_properties_name: string (nullable = true)
# -- features_properties_state: string (nullable = true)
# -- features_properties_zone: string (nullable = true)
#
# </div>

# %% [markdown]
# #Converting spark dataframe to Pandas dataframe
#
# (why means to get a clear overview of data )(not mandatory*) i done it for my comfortness .

# %%
convpandas = df_flatten.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
convpandas.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features_geometry_coordinates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>17394.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>51.193171</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>29.273613</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>8.088028</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>23.427799</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>51.353188</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>78.945682</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>95.725374</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
convpandas.describe(include="object")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>features_type</th>
#       <th>features_geometry_type</th>
#       <th>features_properties_address</th>
#       <th>features_properties_code</th>
#       <th>features_properties_name</th>
#       <th>features_properties_state</th>
#       <th>features_properties_zone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>17687</td>
#       <td>17687</td>
#       <td>17394</td>
#       <td>8728</td>
#       <td>17687</td>
#       <td>17687</td>
#       <td>8728</td>
#       <td>8728</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2724</td>
#       <td>8990</td>
#       <td>8937</td>
#       <td>30</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>FeatureCollection</td>
#       <td>Feature</td>
#       <td>Point</td>
#       <td></td>
#       <td>SVH</td>
#       <td>MAULA ALI</td>
#       <td>Uttar Pradesh</td>
#       <td>NR</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>17687</td>
#       <td>17687</td>
#       <td>17394</td>
#       <td>118</td>
#       <td>2</td>
#       <td>6</td>
#       <td>1052</td>
#       <td>1177</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
convpandas.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 17687 entries, 0 to 17686
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   type                           17687 non-null  object
#  1   features_type                  17687 non-null  object
#  2   features_geometry_coordinates  17394 non-null  float64
#  3   features_geometry_type         17394 non-null  object
#  4   features_properties_address    8728 non-null   object
#  5   features_properties_code       17687 non-null  object
#  6   features_properties_name       17687 non-null  object
#  7   features_properties_state      8728 non-null   object
#  8   features_properties_zone       8728 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 1.2+ MB
# </div>

# %%
convpandas.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: type                                0
# features_type                       0
# features_geometry_coordinates     293
# features_geometry_type            293
# features_properties_address      8959
# features_properties_code            0
# features_properties_name            0
# features_properties_state        8959
# features_properties_zone         8959
# dtype: int64</div>

# %% [markdown]
# #Importing the required library and profiling the data

# %%
import json
from dataprofiler import Data, Profiler
import dataprofiler as dp
from pyspark.sql.types import StructType, StringType, StructField, IntegerType
from pyspark.sql import SparkSession
from pyspark.sql import Row

import pandas as pd
my_dataframe = spark.read.format("json").load("dbfs:/mnt/tf-abfss/bronze/indian_railways/stations.json").toPandas()
data = dp.Profiler(my_dataframe)

report  = data.report(report_options={"output_format":"pretty"})
print(json.dumps(report, indent=4))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/conversion.py:92: UserWarning: toPandas attempted Arrow optimization because &#39;spark.sql.execution.arrow.pyspark.enabled&#39; is set to true; however, failed by the reason below:
#   Unable to convert the field features. If this column is not necessary, you may consider dropping it or converting to primitive type before the conversion.
# Direct cause: Unsupported type in conversion to Arrow: ArrayType(StructType(List(StructField(geometry,StructType(List(StructField(coordinates,ArrayType(DoubleType,true),true),StructField(type,StringType,true))),true),StructField(properties,StructType(List(StructField(address,StringType,true),StructField(code,StringType,true),StructField(name,StringType,true),StructField(state,StringType,true),StructField(zone,StringType,true))),true),StructField(type,StringType,true))),true)
# Attempting non-optimization as &#39;spark.sql.execution.arrow.pyspark.fallback.enabled&#39; is set to true.
#   warnings.warn(msg)
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...
# 100%|██████████| 2/2 [00:00&lt;00:00, 24.35it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...  (with 4 processes)
# 100%|██████████| 2/2 [00:10&lt;00:00,  5.43s/it]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2526c91b-4649-40a5-af21-4262544be910/lib/python3.8/site-packages/dataprofiler/profilers/numerical_column_stats.py:737: RuntimeWarning: Insufficient match count to correct bias in variance. Bias correction can be manually disabled by setting bias_correction.is_enabled to False in ProfilerOptions.
#   warnings.warn(
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2526c91b-4649-40a5-af21-4262544be910/lib/python3.8/site-packages/dataprofiler/profilers/numerical_column_stats.py:818: RuntimeWarning: Insufficient match count to correct bias in skewness. Bias correctioncan be manually disabled by setting bias_correction.is_enabled toFalse in ProfilerOptions.
#   warnings.warn(
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2526c91b-4649-40a5-af21-4262544be910/lib/python3.8/site-packages/dataprofiler/profilers/numerical_column_stats.py:917: RuntimeWarning: Insufficient match count to correct bias in kurtosis. Bias correctioncan be manually disabled by setting bias_correction.is_enabled toFalse in ProfilerOptions.
#   warnings.warn(
# {
#     &#34;global_stats&#34;: {
#         &#34;samples_used&#34;: 1,
#         &#34;column_count&#34;: 2,
#         &#34;row_count&#34;: 1,
#         &#34;row_has_null_ratio&#34;: 0.0,
#         &#34;row_is_null_ratio&#34;: 0.0,
#         &#34;unique_row_ratio&#34;: 1.0,
#         &#34;duplicate_row_count&#34;: 0,
#         &#34;file_type&#34;: &#34;&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;&#34;,
#         &#34;encoding&#34;: null,
#         &#34;correlation_matrix&#34;: null,
#         &#34;chi2_matrix&#34;: &#34;[[1.        , 0.15729921],\n [0.15729921, 1.        ]]&#34;,
#         &#34;profile_schema&#34;: {
#             &#34;features&#34;: [
#                 0
#             ],
#             &#34;type&#34;: [
#                 1
#             ]
#         },
#         &#34;times&#34;: {
#             &#34;row_stats&#34;: 0.098
#         }
#     },
#     &#34;data_stats&#34;: [
#         {
#             &#34;column_name&#34;: &#34;features&#34;,
#             &#34;data_type&#34;: &#34;text&#34;,
#             &#34;data_label&#34;: &#34;UNKNOWN&#34;,
#             &#34;categorical&#34;: true,
#             &#34;order&#34;: &#34;constant value&#34;,
#             &#34;samples&#34;: &#34;[\&#34;[Row(geometry=Row(coordinates=[75.4516454, 27.2520587], type=&#39;Point&#39;), properties=Row(address=&#39;Kishangarh Renwal, Rajasthan&#39;, code=&#39;BDHL&#39;, name=&#39;Badhal&#39;, state=&#39;Rajasthan&#39;, zone=&#39;NWR&#39;), type=&#39;Feature&#39;), Row(geometry=None, properties=Row(address=None, code=&#39;XX-BECE&#39;, name=&#39;XX-BECE&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=None, properties=Row(address=None, code=&#39;XX-BSPY&#39;, name=&#39;XX-BSPY&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=None, properties=Row(address=None, code=&#39;YY-BPLC&#39;, name=&#39;YY-BPLC&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[79.519746, 28.913427000000002], type=&#39;Point&#39;), properties=Row(address=&#39;Kichha, Uttar Pradesh&#39;, code=&#39;KHH&#39;, name=&#39;KICHHA&#39;, state=&#39;Uttar Pradesh&#39;, zone=&#39;NER&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[74.43499088287354, 29.55519806064484], type=&#39;Point&#39;), properties=Row(address=&#39;MDR 89, Rajasthan&#39;, code=&#39;SRKN&#39;, name=&#39;Sherekan&#39;, state=&#39;Rajasthan&#39;, zone=&#39;NWR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[74.75103096105158, 29.238227312503696], type=&#39;Point&#39;), properties=Row(address=&#39;Bhukarka, Rajasthan&#39;, code=&#39;BKKA&#39;, name=&#39;Bhukarka&#39;, state=&#39;Rajasthan&#39;, zone=&#39;NWR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[74.77362781763077, 29.192562738768984], type=&#39;Point&#39;), properties=Row(address=&#39;State Highway 36, Rajasthan&#39;, code=&#39;NHR&#39;, name=&#39;Nohar&#39;, state=&#39;Rajasthan&#39;, zone=&#39;NWR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[80.231363, 12.975217], type=&#39;Point&#39;), properties=Row(address=&#39;Chennai, Tamil Nadu&#39;, code=&#39;PRGD&#39;, name=&#39;Perungudi&#39;, state=&#39;Tamil Nadu&#39;, zone=&#39;SR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[74.7179570607841, 29.345637263205944], type=&#39;Point&#39;), properties=Row(address=&#39;State Highway 23, Haryana&#39;, code=&#39;KNNA&#39;, name=&#39;Khinaniyan&#39;, state=&#39;Haryana&#39;, zone=&#39;NWR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[78.216684, 21.838466], type=&#39;Point&#39;), properties=Row(address=None, code=&#39;JKR&#39;, name=&#39;JAULKHERA&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[78.03136099999999, 21.909813], type=&#39;Point&#39;), properties=Row(address=None, code=&#39;BYS&#39;, name=&#39;BARSALI&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[78.936311, 23.838185999999997], type=&#39;Point&#39;), properties=Row(address=None, code=&#39;GW&#39;, name=&#39;GIRWAR&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[79.019912, 23.871771000000003], type=&#39;Point&#39;), properties=Row(address=None, code=&#39;DGD&#39;, name=&#39;DANGIDHAR&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[75.10354600000001, 23.770740999999997], type=&#39;Point&#39;), properties=Row(address=&#39;Dhodar, Madhya Pradesh&#39;, code=&#39;DOD&#39;, name=&#39;DHODHAR&#39;, state=&#39;Madhya Pradesh&#39;, zone=&#39;WR&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[79.074633, 23.895862], type=&#39;Point&#39;), properties=Row(address=None, code=&#39;GAJ&#39;, name=&#39;GANESHGANJ&#39;, state=None, zone=None), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[88.415324, 22.168635], type=&#39;Point&#39;), properties=Row(address=&#39;Jaynagar, West Bengal&#39;, code=&#39;JNM&#39;, name=&#39;Jayanagar Majilpur Halt&#39;, state=&#39;West Bengal&#39;, zone=&#39;ER&#39;), type=&#39;Feature&#39;), Row(geometry=Row(coordinates=[74.71699100000001, 26.294459999999997], type=&#39;Point&#39;), properties=Row(address=&#39;Nas ...
